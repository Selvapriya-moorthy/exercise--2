# %% [markdown]
# <a href="https://colab.research.google.com/github/Selvapriya-moorthy/exercise--2/blob/main/_exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
    def _init_(self, name, rollNumber):
        self.name = name
        self.rollNumber = rollNumber

    def display(self):
        print("Name:", self.name)
        print("Roll Number:", self.rollNumber)



class UndergraduateStudent(Student):
    def _init_(self, name, rollNumber, m1, m2, m3):
        super()._init_(name, rollNumber)
        self.marks = [m1, m2, m3]

    def calculateAverage(self):
        return sum(self.marks) / 3


    def display(self):
        average = self.calculateAverage()
        print("Undergraduate Student")
        print("Name:", self.name)
        print("Average Marks:", average)



class PostgraduateStudent(Student):
    def _init_(self, name, rollNumber, m1, m2, m3, m4):
        super()._init_(name, rollNumber)
        self.marks = [m1, m2, m3, m4]

    def calculateAverage(self):
        return sum(self.marks) / 4


    def display(self):
        average = self.calculateAverage()
        print("Postgraduate Student")
        print("Name:", self.name)
        print("Average Marks:", average)



def main():

    under= Undergraduatetudent("priya, 105, 75, 90, 88)


    post = PostgraduateStudent("john", 205, 80, 85, 95, 70)


    under.display()

    post.display()



if _name_ == "_main_":
    main()
